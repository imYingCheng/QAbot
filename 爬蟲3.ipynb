# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import bs4
import requests as req
import json

with open('/content/drive/MyDrive/Colab Notebooks/data/Stupid_QA_4_Question.json', 'r', encoding='UTF-8') as f:
	JsonList = json.load(f)
a=[]

for num in range(140,200): #第一部分range 0-70 第二70-140 第三140-200
  query = JsonList[num]['Question']

  ans=[JsonList[num]['A'],JsonList[num]['B'],JsonList[num]['C']]
  url = 'https://www.google.com/search?q={}'.format(query) 
  r = req.get(url)
  
  
  
  root = bs4.BeautifulSoup(r.text,"html.parser")
  ment = str(root.find_all("h3"))
  #title = ment.select_one("div").getText()
  
  tmp=0
  pp=-1
  for i in ans:
    if i in ment:
      anss=i
      pp=tmp
    tmp+=1
  
  if pp==0:
    answer='A'
  elif pp==1:
    answer='B'
  elif pp==2:
    answer='C'
  else:
    answer='None'

  # print(answer)
  #if(answer=='None'):
    #print(num+1)  #
  a.append(answer)
print(json.dumps(a))
print()
# Out:
# ["A", "B", "C", "A", "A", "None", "A", "None", "None", "A", "None", "B", "None", "None", "C", "None", "C", "C", "A", "None", "None", "B", "None", "None", "C", "A", "C", "None", "B", "A", "B", "C", "None", "C", "B", "B", "A", "A", "C", "None", "A", "B", "B", "None", "C", "B", "A", "None", "C", "C", "B", "A", "None", "None", "A", "None", "B", "None", "None", "None"]

# %%
import json
import requests as req


question_url = "https://www.dropbox.com/s/kq678nfffzta5zg/20_Question.json?dl=1" #輸入老師給的網址
JsonList = req.get(question_url).json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-7e2899812677> in <module>
#       4
#       5 question_url = "https://drive.google.com/file/d/1hp1RZnDYnFxOk0o1zpU1RexJgTr7SLLL/view?usp=share_link" #輸入老師給的網址
# ----> 6 JsonList = req.get(question_url).json()
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# /usr/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /usr/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
import bs4


a=[]

for num in range(140,200): #第一部分range 0-70 第二70-140 第三140-200
  query = JsonList[num]['Question']

  ans=[JsonList[num]['A'],JsonList[num]['B'],JsonList[num]['C']]
  url = 'https://www.google.com/search?q={}'.format(query) 
  r = req.get(url)
  
  
  
  root = bs4.BeautifulSoup(r.text,"html.parser")
  ment = str(root.find_all("h3"))
  #title = ment.select_one("div").getText()
  
  tmp=0
  pp=-1
  for i in ans:
    if i in ment:
      anss=i
      pp=tmp
    tmp+=1
  
  if pp==0:
    answer='A'
  elif pp==1:
    answer='B'
  elif pp==2:
    answer='C'
  else:
    answer='None'

  # print(answer)
  #if(answer=='None'):
    #print(num+1)  #
  a.append(answer)
print(json.dumps(a))
print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-438385ed7aeb> in <module>
#       6
#       7 for num in range(140,200): #第一部分range 0-70 第二70-140 第三140-200
# ----> 8   query = JsonList[num]['Question']
#       9
#      10   ans=[JsonList[num]['A'],JsonList[num]['B'],JsonList[num]['C']]
#
# IndexError: list index out of range
