# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import bs4
import requests as req
import json

with open('/content/drive/MyDrive/Colab Notebooks/data/Stupid_QA_4_Question.json', 'r', encoding='UTF-8') as f:
	JsonList = json.load(f)
a=[]

for num in range(0,70): #第一部分range 0-70 第二70-140 第三140-200
  query = JsonList[num]['Question']

  ans=[JsonList[num]['A'],JsonList[num]['B'],JsonList[num]['C']]
  url = 'https://www.google.com/search?q={}'.format(query) 
  r = req.get(url)
  
  
  
  root = bs4.BeautifulSoup(r.text,"html.parser")
  ment = str(root.find_all("h3"))
  #title = ment.select_one("div").getText()
  
  tmp=0
  pp=-1
  for i in ans:
    if i in ment:
      anss=i
      pp=tmp
    tmp+=1
  
  if pp==0:
    answer='A'
  elif pp==1:
    answer='B'
  elif pp==2:
    answer='C'
  else:
    answer='None'

  # print(answer)
  if(answer=='None'):
    print(num+1)  #
  a.append(answer)
print(json.dumps(a))
print("")
# Out:
# 2
# 3
# 4
# 6
# 7
# 9
# 17
# 18
# 19
# 20
# 23
# 25
# 26
# 28
# 29
# 30
# 31
# 43
# 45
# 46
# 48
# 50
# 51
# 52
# 54
# 55
# 56
# 57
# 63
# 66
# 70
# ["A", "None", "None", "None", "C", "None", "None", "B", "None", "B", "B", "B", "B", "A", "B", "A", "None", "None", "None", "None", "B", "C", "None", "B", "None", "None", "B", "None", "None", "None", "None", "C", "C", "A", "B", "C", "A", "B", "C", "B", "A", "B", "None", "B", "None", "None", "A", "None", "C", "None", "None", "None", "C", "None", "None", "None", "None", "A", "A", "A", "C", "B", "None", "B", "B", "None", "A", "C", "B", "None"]

# %%
import json
import requests as req


question_url = "https://www.dropbox.com/s/kq678nfffzta5zg/20_Question.json?dl=1" #輸入老師給的網址
JsonList = req.get(question_url).json()

# %%
import requests
import bs4

a=[]

for num in range(0,70): #第一部分range 0-70 第二70-140 第三140-200
  query = JsonList[num]['Question']

  ans=[JsonList[num]['A'],JsonList[num]['B'],JsonList[num]['C']]
  url = 'https://www.google.com/search?q={}'.format(query) 
  r = req.get(url)
  
  
  
  root = bs4.BeautifulSoup(r.text,"html.parser")
  ment = str(root.find_all("h3"))
  #title = ment.select_one("div").getText()
  
  tmp=0
  pp=-1
  for i in ans:
    if i in ment:
      anss=i
      pp=tmp
    tmp+=1
  
  if pp==0:
    answer='A'
  elif pp==1:
    answer='B'
  elif pp==2:
    answer='C'
  else:
    answer='None'

  # print(answer)
  if(answer=='None'):
    print(num+1)  #
  a.append(answer)
print(json.dumps(a))
print("")
# Out:
# 6
# 8
# 13
# 17
# 18
# 19
# 24
# 25
# 27
# 43
# 45
# 47
# 63
# 65
# 66
# ["B", "C", "B", "A", "A", "None", "A", "None", "B", "C", "B", "B", "None", "B", "A", "C", "None", "None", "None", "A", "B", "B", "B", "None", "None", "A", "None", "C", "B", "B", "B", "B", "B", "A", "B", "A", "B", "C", "C", "A", "C", "A", "None", "A", "None", "A", "None", "C", "B", "B", "B", "C", "C", "B", "A", "A", "C", "A", "C", "C", "B", "B", "None", "B", "None", "None", "C", "B", "B", "A"]
